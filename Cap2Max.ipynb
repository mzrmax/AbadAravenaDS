# %% [markdown]
# <a href="https://colab.research.google.com/github/mzrmax/AbadAravenaDS/blob/main/Cap2Max.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Capitulo 2 - HML

# %%
Hola, probando
